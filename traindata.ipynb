# %%
import os 
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
train_data=pd.read_csv(r"C:\Users\gpkt2\OneDrive\Desktop\job_assignment\DATA SCIENTIST_ASSIGNMENT-20250423T114630Z-001\DATA SCIENTIST_ASSIGNMENT\Licplatesdetection_train.csv")
train_data.head()
# Out:
#     img_id  ymin  xmin  ymax  xmax
# 0    1.jpg   276    94   326   169
# 1   10.jpg   311   395   344   444
# 2  100.jpg   406   263   450   434
# 3  101.jpg   283   363   315   494
# 4  102.jpg   139    42   280   222

# %%
image_path = r"C:\Users\gpkt2\OneDrive\Desktop\job_assignment\DATA SCIENTIST_ASSIGNMENT-20250423T114630Z-001\DATA SCIENTIST_ASSIGNMENT\Licplatesdetection_train\license_plates_detection_train\1.jpg"
x = cv2.imread(image_path)

# (xmin, ymin), (xmax, ymax)
x = cv2.rectangle(x, (94, 276), (169, 326), (0, 255, 0), 2)

# Convert BGR to RGB
x_rgb = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
plt.imshow(x_rgb)
plt.axis('off')
plt.show()

# %%
base_path = r"C:\Users\gpkt2\OneDrive\Desktop\job_assignment\DATA SCIENTIST_ASSIGNMENT-20250423T114630Z-001\DATA SCIENTIST_ASSIGNMENT\Licplatesdetection_train.csv"

# Load your CSV
df = pd.read_csv(r"C:\Users\gpkt2\OneDrive\Desktop\job_assignment\DATA SCIENTIST_ASSIGNMENT-20250423T114630Z-001\DATA SCIENTIST_ASSIGNMENT\Licplatesdetection_train.csv")
for idx,row in df.head(5).iterrows():
    img_path=os.path.join(base_path,row['img_id'])
    img=cv2.imread(image_path)
    img=cv2.rectangle(img, 
        (row['xmin'], row['ymin']), 
        (row['xmax'], row['ymax']), 
        (0, 255, 0), 2)
    x_rg=cv2.cvtColor(x,cv2.COLOR_BGR2RGB)
    plt.imshow(x_rgb)
    plt.axis('off')
    plt.show()
